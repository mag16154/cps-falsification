# %%
import matplotlib

# %matplotlib inline

from compute_vprime_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Brussellator')

nnObject.setSteps(1000)

nnObject.setLowerBound([-10.0, -10.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# [-7.5533289354227895, -1.7119596078757127, -1.2482586186989186, 7.33567459759951, 0.4639969319009743, 0.9948148772806902]
# [0.09355418 0.56450218]
# [ 0.95714661  1.81792366  0.08813534 -0.0884865   1.05409835  1.71903125]
# [ 0.5301095   1.38837124 -0.21204467 -2.14601394  1.02762087  1.74622975]
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.013730839384957984
# Mean relative error 0.6644293434314358
# Mean sorted error 1.2663873293302104

# %%
import matplotlib

# %matplotlib inline

from compute_vprime_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Roesseler', dimensions=3)

nnObject.setSteps(1000)
nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
nnObject.setNeurons([40, 25, 20])
nnObject.setLayers(3)
nnObject.createNN()
nnObject.trainTestNN(act_fn='logistic', solver_fn='lbfgs')
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 10.25646167246857
# Mean relative error 0.824709105869821
# Mean sorted error 1.149998974565967
