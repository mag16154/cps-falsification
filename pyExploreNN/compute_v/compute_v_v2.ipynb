# %%
import matplotlib

# %matplotlib inline

from compute_v_v2 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Brussellator')

nnObject.setSteps(1000)

nnObject.setLowerBound([-10.0, -10.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.004119626784128333
# Mean relative error 0.0585602980628025
# Mean sorted error 0.9965928811764363
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.006883188222739861
# Mean relative error 0.13841153954520247
# Mean sorted error 1.0404612986600856
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.03531554206355336
# Mean relative error 0.2291929580682848
# Mean sorted error 1.0976963299845761

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Gravity')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.189517384643671
# Mean relative error 0.15867436091180362
# Mean sorted error 1.06128933554735
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.2299557207323463
# Mean relative error 0.15704774333476815
# Mean sorted error 1.053456248914546
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.2897043475113336
# Mean relative error 0.17283962344234727
# Mean sorted error 1.0419094292166824

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Buckling')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 180.33829545153523
# Mean relative error 1.1803828158300764
# Mean sorted error 1.0041620624740828
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 130.09513352129707
# Mean relative error 1.1185572307246787
# Mean sorted error 1.1151135009987527
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 122.75374534385672
# Mean relative error 1.1740792188794662
# Mean sorted error 1.077510012988853

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Lotka')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 3.0615284636096343
# Mean relative error 1.333484552146106
# Mean sorted error 1.6496935186732582
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 3.2071225706169786
# Mean relative error 1.1951210047600653
# Mean sorted error 1.4837931900085841
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 3.3533842173021347
# Mean relative error 1.3176884054654057
# Mean sorted error 1.6303263663067689

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Jetengine')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.18203885561879418
# Mean relative error 3.020861986195407
# Mean sorted error 3.2360346131845916
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.2366559603812636
# Mean relative error 7.399305568628398
# Mean sorted error 7.53459351348804
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.21198105889236857
# Mean relative error 5.785268130223497
# Mean sorted error 6.044883934198824

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Vanderpol')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.3787381720087648
# Mean relative error 0.27603476848920333
# Mean sorted error 1.1028209123998554
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.34090979929102394
# Mean relative error 0.30581150674603275
# Mean sorted error 1.1264522407579456
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.3615536088994756
# Mean relative error 0.3020665935433562
# Mean sorted error 1.1370731996389158

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Roesseler', dimensions=3)

nnObject.setSteps(1000)
nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
#nnObject.setNeurons([40, 25, 20])
#nnObject.setLayers(3)
for jump_size in [1,2,4]:
    nnObject.createNN()
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 20.421488880595003
# Mean relative error 0.7481976121274362
# Mean sorted error 0.9628810752329787
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 19.96734579547026
# Mean relative error 0.7244364499298885
# Mean sorted error 0.9781986817122432
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 19.32119666831552
# Mean relative error 0.7153356042075554
# Mean sorted error 1.0087610144041947

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Lorentz', dimensions=3)

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 53.27004986581655
# Mean relative error 1.1220291245416187
# Mean sorted error 1.0844125046149222
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 50.64748829293717
# Mean relative error 1.139644557402429
# Mean sorted error 0.9757381896446987
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 53.6840511004257
# Mean relative error 1.169308999501365
# Mean sorted error 1.066529587055875

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Steam', dimensions=3)

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 1.465236179664176
# Mean relative error 0.1344752437321338
# Mean sorted error 0.9981842611316402
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 2.105975329816165
# Mean relative error 0.17130508993421834
# Mean sorted error 1.002803837762165
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 2.3009371807392713
# Mean relative error 0.1869367262295037
# Mean sorted error 1.011523532499022

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='SpringPendulum', dimensions=4)

nnObject.setSteps(1000)

nnObject.setLowerBound([1.19, 0.49, 0.0, 0.0])
nnObject.setUpperBound([1.21, 0.51, 0.0, 0.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0005326296493086477
# Mean relative error 4.7769468556893635
# Mean sorted error 4.660788074004851
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0005717032482253728
# Mean relative error 5.470897387137661
# Mean sorted error 5.362916762675107
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0005693436674409556
# Mean relative error 6.787702945688125
# Mean sorted error 6.69186659909618

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='CoupledVanderpol', dimensions=4)

nnObject.setSteps(1000)

nnObject.setLowerBound([1.25, 2.25, 1.25, 2.25])
nnObject.setUpperBound([1.28, 2.35, 1.28, 2.35])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0005773148057577944
# Mean relative error 2.609140754817801
# Mean sorted error 2.434952835978397
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.00044245394450560696
# Mean relative error 3.046295056117466
# Mean sorted error 2.8903342074692233
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0004817874263913614
# Mean relative error 2.9803999310031593
# Mean sorted error 2.8339693981817957

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='BiologicalModel1', dimensions=7)

nnObject.setSteps(1000)

nnObject.setLowerBound([0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99])
nnObject.setUpperBound([1.01, 1.01, 1.01, 1.01, 1.01, 1.01, 1.01])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 5.08852127095794e-05
# Mean relative error 0.7487076310257549
# Mean sorted error 0.7890726905257415
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 5.469219643872515e-05
# Mean relative error 0.8046240216117982
# Mean sorted error 0.7859891292248664
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 5.149039866708453e-05
# Mean relative error 0.6908399938835128
# Mean sorted error 0.8458709127299359
