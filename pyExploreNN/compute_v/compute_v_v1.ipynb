# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Brussellator')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.416353361715305
# Mean relative error 2.3325294660215694
# Mean sorted error 2.094866618501114

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Gravity')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.20508790451633005
# Mean relative error 0.08139676638012706
# Mean sorted error 1.0034903416418117

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Buckling')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 145.38369038092765
# Mean relative error 1.0211046783160236
# Mean sorted error 1.1966979858972882

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Lotka')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 3.121357760819203
# Mean relative error 0.8289077222546583
# Mean sorted error 1.1966729911366838

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Jetengine')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.15139533358408258
# Mean relative error 1.6573563702328162
# Mean sorted error 1.9805572406591574

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Vanderpol')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.4024662136414027
# Mean relative error 0.206514407854674
# Mean sorted error 1.032778134497822

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Roesseler', dimensions=3)

nnObject.setSteps(1000)
nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
#nnObject.setNeurons([40, 25, 20])
#nnObject.setLayers(3)
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 10.520745047281686
# Mean relative error 0.5703150878163344
# Mean sorted error 0.9541827643390043

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Lorentz', dimensions=3)

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 44.36964592934413
# Mean relative error 1.0483069297645449
# Mean sorted error 1.1296175485580706

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Steam', dimensions=3)

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 2.0527989973935448
# Mean relative error 0.16817543054882994
# Mean sorted error 1.0023993857497195

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='SpringPendulum', dimensions=4)

nnObject.setSteps(1000)

nnObject.setLowerBound([1.19, 0.49, 0.0, 0.0])
nnObject.setUpperBound([1.21, 0.51, 0.0, 0.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0005807489879579983
# Mean relative error 6.369652640875783
# Mean sorted error 6.287217276612433

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='CoupledVanderpol', dimensions=4)

nnObject.setSteps(1000)

nnObject.setLowerBound([1.25, 2.25, 1.25, 2.25])
nnObject.setUpperBound([1.28, 2.35, 1.28, 2.35])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.00040903511459952
# Mean relative error 2.8242193241335736
# Mean sorted error 2.658990971675147

# %%
import matplotlib

# %matplotlib inline

from compute_v_v1 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='BiologicalModel1', dimensions=7)

nnObject.setSteps(1000)

nnObject.setLowerBound([0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99])
nnObject.setUpperBound([1.01, 1.01, 1.01, 1.01, 1.01, 1.01, 1.01])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 4.449849040711047e-05
# Mean relative error 0.8239199534255718
# Mean sorted error 0.8542937215770781
