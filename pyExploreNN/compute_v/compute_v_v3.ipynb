# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Brussellator')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.5657604865363222
# Mean relative error 43.889151978259655
# Mean sorted error 43.76390962974876

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Gravity')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.8759799824248523
# Mean relative error 0.31633643962609054
# Mean sorted error 1.0756741539100798

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Buckling')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 75.97812432956387
# Mean relative error 1.1723018991423195
# Mean sorted error 1.231800096456836

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Lotka')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 7.338502909113583
# Mean relative error 1.817020287079287
# Mean sorted error 1.6527831984578525

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Jetengine')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.27881225579947516
# Mean relative error 1.8873791077004423
# Mean sorted error 1.5356232376864503

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Vanderpol')

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 1.4434513835189335
# Mean relative error 0.9400989356668665
# Mean sorted error 1.4473251400030591

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Roesseler', dimensions=3)

nnObject.setSteps(1000)
nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
#nnObject.setNeurons([40, 25, 20])
#nnObject.setLayers(3)
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 18.53268873095245
# Mean relative error 1.029005243906186
# Mean sorted error 0.8533708757228606

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Lorentz', dimensions=3)

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 56.903579376405894
# Mean relative error 1.2418072916632208
# Mean sorted error 1.1616628913350877

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Steam', dimensions=3)

nnObject.setSteps(1000)

nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 1.4357177115028703
# Mean relative error 0.22054946175830234
# Mean sorted error 0.9757387150387807

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='SpringPendulum', dimensions=4)

nnObject.setSteps(1000)

nnObject.setLowerBound([1.19, 0.49, 0.0, 0.0])
nnObject.setUpperBound([1.21, 0.51, 0.0, 0.0])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0013968285638330195
# Mean relative error 7.432832840085636
# Mean sorted error 7.386379844980189

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='CoupledVanderpol', dimensions=4)

nnObject.setSteps(1000)

nnObject.setLowerBound([1.25, 2.25, 1.25, 2.25])
nnObject.setUpperBound([1.28, 2.35, 1.28, 2.35])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0018032249230520454
# Mean relative error 6.020098387592019
# Mean sorted error 5.857157003824646

# %%
import matplotlib

# %matplotlib inline

from compute_v_v3 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='BiologicalModel1', dimensions=7)

nnObject.setSteps(1000)

nnObject.setLowerBound([0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99])
nnObject.setUpperBound([1.01, 1.01, 1.01, 1.01, 1.01, 1.01, 1.01])

nnObject.generateTrajectories()
nnObject.createNN()
nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0004868257843435729
# Mean relative error 2.7946783037928813
# Mean sorted error 2.6963474546286412
