# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Brussellator')

nnObject.setSteps(4000)

nnObject.setLowerBound([-10.0, -10.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.009091751934085207
# Mean relative error 0.086571598295204
# Mean sorted error 1.0283731724868388
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.025616886012881958
# Mean relative error 0.25808963348234815
# Mean sorted error 1.1164777646198178
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.02532585250602225
# Mean relative error 34.790212479533785
# Mean sorted error 35.13946654658722

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Gravity')

nnObject.setSteps(4000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.021931614159244998
# Mean relative error 0.04244896361499542
# Mean sorted error 1.0079007739283368
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.06318373892062411
# Mean relative error 0.06596710520573211
# Mean sorted error 1.0193490575619968
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.04542825269452988
# Mean relative error 0.04125665508215877
# Mean sorted error 1.005962968419482

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Buckling')

nnObject.setSteps(4000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.011235387428898316
# Mean relative error 0.017225563093635186
# Mean sorted error 1.0007653403256964
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.018320019264969786
# Mean relative error 0.027438893217922772
# Mean sorted error 0.9970255687652848
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.02165021232319547
# Mean relative error 0.04845178883868207
# Mean sorted error 1.0013753590336347

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Lotka')

nnObject.setSteps(4000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0021636185327979706
# Mean relative error 0.03620187833816368
# Mean sorted error 0.9957925098271415
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0020535435851261963
# Mean relative error 0.02906790033695079
# Mean sorted error 0.998386958563289
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.002672352236952548
# Mean relative error 0.02945738460691288
# Mean sorted error 0.9997943328858026

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Jetengine')

nnObject.setSteps(4000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.000971291601442877
# Mean relative error 0.2471600185516751
# Mean sorted error 1.0807411516735113
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0011497344340289624
# Mean relative error 1.030550600242917
# Mean sorted error 1.71753195555116
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0017379145287840787
# Mean relative error 64.77008889066019
# Mean sorted error 65.12636438471833

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Vanderpol')

nnObject.setSteps(4000)

nnObject.setLowerBound([0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.002436237368277652
# Mean relative error 0.019074749295675916
# Mean sorted error 1.0024420018134723
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0039938693847537815
# Mean relative error 0.021248223370147982
# Mean sorted error 1.0049142702629157
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.006682508296350669
# Mean relative error 0.028151585173722994
# Mean sorted error 1.0038373265909035

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Roesseler', dimensions=3)

nnObject.setSteps(4000)
nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
#nnObject.setNeurons([40, 25, 20])
#nnObject.setLayers(3)
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.008150020041014413
# Mean relative error 0.017454369414695487
# Mean sorted error 1.0001765076560334
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.00662890845814922
# Mean relative error 0.015899584358479053
# Mean sorted error 1.0006904687068592
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.018460715762217254
# Mean relative error 0.023071399080882637
# Mean sorted error 1.0001450543999606

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Lorentz', dimensions=3)

nnObject.setSteps(4000)

nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.015338531545267695
# Mean relative error 0.022240531232692786
# Mean sorted error 1.000261387559563
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.024976927019918927
# Mean relative error 0.024772365369276343
# Mean sorted error 1.0020104890981765
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.031976851292401735
# Mean relative error 0.025329695503668707
# Mean sorted error 1.0017703101677902

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='Steam', dimensions=3)

nnObject.setSteps(4000)

nnObject.setLowerBound([0.0, 0.0, 0.0])
nnObject.setUpperBound([10.0, 10.0, 10.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.01082917771001417
# Mean relative error 0.015047987904382661
# Mean sorted error 1.0002553494944078
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.31629765140056115
# Mean relative error 0.03285383829221121
# Mean sorted error 0.9977054206790091
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 17.292522545777636
# Mean relative error 0.13782104713552584
# Mean sorted error 0.995290787804384

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='SpringPendulum', dimensions=4)

nnObject.setSteps(4000)

nnObject.setLowerBound([1.19, 0.49, 0.0, 0.0])
nnObject.setUpperBound([1.21, 0.51, 0.0, 0.0])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.00019630069015053313
# Mean relative error 3.565736478321348
# Mean sorted error 3.4899453660759447
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.00019596470541928903
# Mean relative error 2.99406489025321
# Mean sorted error 2.9877568196666977
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 0.0001620004679730468
# Mean relative error 2.051525085457951
# Mean sorted error 2.046005417395304

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='CoupledVanderpol', dimensions=4)

nnObject.setSteps(4000)

nnObject.setLowerBound([1.25, 2.25, 1.25, 2.25])
nnObject.setUpperBound([1.28, 2.35, 1.28, 2.35])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 5.956535890033939e-05
# Mean relative error 1.177269586055852
# Mean sorted error 1.4630690893610516
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 7.353216559012247e-05
# Mean relative error 1.4081607835706123
# Mean sorted error 1.6690151542097076
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 6.988727075897866e-05
# Mean relative error 1.401011214679547
# Mean sorted error 1.6686275617883517

# %%
import matplotlib

# %matplotlib inline

from compute_v_v4 import nnOnStateSpace

# time step default = 0.01, number of steps default = 100
# dimensions default = 2, number of sample default = 50

nnObject = nnOnStateSpace(dynamics='BiologicalModel1', dimensions=7)

nnObject.setSteps(4000)

nnObject.setLowerBound([0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99])
nnObject.setUpperBound([1.01, 1.01, 1.01, 1.01, 1.01, 1.01, 1.01])

nnObject.generateTrajectories()
for jump_size in [1,2,4]:
    nnObject.createNN(jump_size)
    nnObject.trainTestNN()
# Out:
# 1
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 2.880506752901738e-05
# Mean relative error 0.8479405126224422
# Mean sorted error 0.682727035799109
# 2
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 3.132913695759611e-05
# Mean relative error 0.8636388496705064
# Mean sorted error 0.7598353316147278
# 4
# 45000
# Y_test length 14850 test_predictions length 14850
# Mean Squared error 3.481961048757983e-05
# Mean relative error 0.8704146113060487
# Mean sorted error 0.7645294550534181
